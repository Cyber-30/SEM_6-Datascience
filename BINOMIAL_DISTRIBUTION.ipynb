# %% [markdown]
# <a href="https://colab.research.google.com/github/Cyber-30/SEM_6-Datascience/blob/main/BINOMIAL_DISTRIBUTION.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Probability that exactly 5 customers will return the items**
#
# The function stats.binom.pmf() calculates PMF for binomial distribution and takes three parameters:
#
#
# *   Expected number of successful trials (5)
# *   Total number of trials (20)
#
# *   The probability of success (0.1)
#
# **Note**: The values in the bracket indicate the value of the parameter

# %%
from scipy import stats
stats.binom.pmf(5,20,0.1)
# Out:
# np.float64(0.031921361119954424)

# %% [markdown]
# The corresponding probability is 0.03192, that is the probability that exactly 5 customers will return the items is approximately 3%.
#
# To visualize how the PMF varies with increasing number of successful trails, we will create a list of all possible number of successes (0 to 20) and corressponding PMF values and draw a bar plot.

# %%
import pandas as pd
import seaborn as sn
import matplotlib.pyplot as plt

# range(0,21) returns all values from 0 to 20 (excluding 21)
pmf_df = pd.DataFrame({'success':range(0,21),'pmf':list(stats.binom.pmf(range(0,21),20,0.1))})

# Creating a bar plot with number of success as x and pmf as y
sn.barplot(x = pmf_df.success, y = pmf_df.pmf)
plt.ylabel('pmf')
plt.xlabel('Number of items returns')
# Out:
# Text(0.5, 0, 'Number of items returns')

# %% [markdown]
# **Probaility that a maximum of 5 customers will return will return the items**
#
# The Class stats.binom.cdf() computes the CDF for binomial distribution. In this case the cumulative distribution function returns the probability that a maximum of 5 customers will return items

# %%
stats.binom.cdf(5, 20, 0.1)
# Out:
# np.float64(0.988746865835491)

# %% [markdown]
# The corresponding probability value is 0.9887

# %% [markdown]
# **Probability that more than 5 customers will return the items purchased by them.**
#
# Total probability of any number of customers returning items (including 0) is always equal to 1.0. So, the probability that more than 5 customers will return the items can be computed by substracting the probability of a maximum of 5 customers will return items from 1.0. In other words, the probability that more than 5 custormers will returns the items can be obtained by tthe computing CDF of 5 and then subtracting it from 0.1

# %%
1 - stats.binom.cdf(5, 20, 0.1)
# Out:
# np.float64(0.011253134164509015)

# %% [markdown]
# The corresponding probaility value is 0.0112

# %% [markdown]
# **Average number of customers who are likely to return the items and the variance and the standard deviation of the number of returns.**
#
#
#
# 1.   Average of a binomial distribution is given by 456$n * p$789
# 2.   Variance of the binomial distribution is give10n by 1112$n * p * (1 - p)$

# %%
mean, var = stats.binom.stats(20, 0.1)
print("Average: ", mean, " Variance:", var)
# Out:
# Average:  2.0  Variance: 1.8

# %% [markdown]
# **Output**: Average: 2.0 Variance: 1.8
